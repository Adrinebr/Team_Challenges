# %%
import numpy as np
import random
import variables as var
import clases as cl
import funciones as fun

#crear jugadores
if __name__ == '__main__': 
    jugador1 = cl.Jugador("Humano")
    jugador2 = cl.Jugador("Máquina")
#crear tableros
    tablero = cl.Tablero 
    mi_tablero = tablero.crear_tablero()
    tablero_rival = tablero.crear_tablero()
    tablero_visible = tablero_rival

#crear flotas
    mis_barcos = fun.crear_flota(mi_tablero)
    barcos_rival = fun.crear_flota(tablero_rival)
    #barcos_ataques = crear_flota(tablero_visible)

while (var.barco in mi_tablero and var.barco in tablero_rival):
        #Turno jugador humano
        while True:
            fun.menu()
            while 1:
                try:
                    print("------------------", "\n",
                          "Tu turno", "\n",
                          "------------------", "\n")
                    opcion = int(input("Elige una opción "))
                    break
                except ValueError:
                    print("Esa opción no es valida", "\n")
                    pass
            if opcion == 1:
                fun.disparo(jugador1 ,tablero_rival)
                break
            elif opcion == 2:
                print(mi_tablero) #Ver tablero propio
                continue
            elif opcion == 3:
                print(tablero_rival) #Ver el tablero rival
                continue
            elif opcion == 4:
                print(tablero_visible) #Opcion bonus: ver donde hemos disparado (in progress)
            elif opcion == 5:
                exit()
                break
               
            else:
                print("No, la opción que has elegido no existe. Prueba de nuevo", "\n")
                continue
        if opcion == 5:
            break
        #Turno del rival
        print("------------------", "\n",
            "Turno del rival", "\n",
            "------------------", "\n")
        fun.disparo(jugador2, mi_tablero)
        
    #Fin del juego
if opcion != 5:
    fun.fin_juego(mi_tablero, tablero_rival)
# Out:
# Opciones de juego:
#  1. Disparar
#  2. Mirar tu tablero
#  3. Mirar tablero rival
#  4. Mirar tablero visible de mis attaques
#  5. Exit
# ------------------
#  Tu turno
#  ------------------
#
# Esa opción no es valida
#
# ------------------
#  Tu turno
#  ------------------
#
# No, la opción que has elegido no existe. Prueba de nuevo
#
# Opciones de juego:
#  1. Disparar
#  2. Mirar tu tablero
#  3. Mirar tablero rival
#  4. Mirar tablero visible de mis attaques
#  5. Exit
# ------------------
#  Tu turno
#  ------------------
#
# Esa opción no es valida
#
# ------------------
#  Tu turno
#  ------------------
#
# Esa opción no es valida
#
# ------------------
#  Tu turno
#  ------------------
#
# Esa opción no es valida
#
# ------------------
#  Tu turno
#  ------------------
#
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' 'O' 'O' ' ' ' ']
#  [' ' 'O' ' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ']
#  [' ' 'O' 'O' 'O' ' ' ' ' ' ' 'O' 'O' ' ']
# ...
